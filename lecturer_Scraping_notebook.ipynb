# %%
import requests
from bs4 import BeautifulSoup
from prettytable import PrettyTable
import pandas as pd
import time

# %%
# URL halaman pertama dari daftar penulis di SINTA
url = "https://sinta.kemdikbud.go.id/affiliations/authors/2053" # anda bisa mengubah kampus dengan menganti kode angka pada tautan setelah authors
response = requests.get(url)

# Cek apakah permintaan berhasil dilakukan
if response.status_code == 200:
    html_content = response.text
else:
    print('Gagal mengambil halaman:', response.status_code)

# %%
# Parsing HTML menggunakan BeautifulSoup
html = response.text
soup = BeautifulSoup(html, 'html.parser')

# Menampilkan struktur HTML yang telah diambil
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    SINTA - Science and Technology Index
#   </title>
#   <meta content="SINTA | Science and Technology Index" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <!-- CSS -->
#   <link href="https://sinta.kemdikbud.go.id/public/assets/img/favicon_sinta.png" rel="shortcut icon" type="image/png"/>
#   <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/bootstrap.min.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/bootstrap-litera.min.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/select2.min.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/select2-bootstrap4.min.css" rel="stylesheet"/>
#   <link href="https://sinta.kemdikbud.go.id/public/assets/css/elusive-icons.min.css" rel="stylesheet"/>
#   <link href="https://sinta.kemdikbud.go.id/public/assets/css/material-design-iconic-font.min.css" rel="stylesheet"/>
#   <link href="https://sinta.kemdikbud.go.id/public/assets/css/animate.css" rel="stylesheet"/>
#   <link href="https://sinta.kemdikbud.go.id/public/assets/css/morphext.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/main.css" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/flag-icons.css" rel="stylesheet">
#     <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/css/responsive.css" rel="stylesheet">
#      <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/plugin/datamaps/datamaps.css" rel="stylesheet">
#       <link crossorigin="anonymous" href="https://sinta.kemdikbud.go.id/public/assets/plugin/autocomplete/jquery.autocomplete.css" rel="stylesheet"/>
#       <!-- <link rel="stylesheet" href="https://sinta.kemdikbud.go.id/public/assets/css/autocomplete.css" crossorigin="anonymous" /> -->
#       <link href="https://sinta.kemdikbud.go.id/public/author/styles/alert.css" rel="stylesheet"/>
#       <link href="//unpkg.com/bootstrap-select@1.12.4/dist/css/bootstrap-select.min.css" rel="stylesheet" type="text/css">
#        <link href="//unpkg.com/bootstrap-select-country@4.0.0/dist/css/bootstrap-select-country.min.css" rel="stylesheet" type="text/css"/>
#        <link href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.9.0/css/bootstrap-datepicker.min.css" rel="stylesheet" type="text/css"/>
#        <style type="text/css">
#         #mynetwork {
#             width: auto;
#             height: 600px;
#             border: 1px solid lightgray;
#         }
#        </style>
#        <!-- <link href="https://cdn.jsdelivr.net/npm/select2@4.1.0-rc.0/dist/css/select2.min.css" rel="stylesheet" /> -->
#        <link href="https://cdn.jsdelivr.net/npm/@ttskch/select2-bootstrap4-theme@x.x.x/dist/select2-bootstrap4.min.css" rel="stylesheet"/>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body>
#   <div class="row no-gutters">
#    <div class="col-md-8">
#     <div class="navi animate__animated animate__slideInDown">
#      <nav class="navbar navbar-expand-md navbar-light bg-light">
#       <a class="navbar-brand" href="https://sinta.kemdikbud.go.id">
#        <img alt="" class="d-inline-block align-top" height="30" loading="lazy" src="https://sinta.kemdikbud.go.id/public/assets/img/brand_sinta.png" width="30"/>
#        <span class="brand-text">
#         SINTA
#        </span>
#       </a>
#       <button class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#        <span class="navbar-toggler-icon">
#        </span>
#       </button>
#       <div class="collapse navbar-collapse" id="navbarNav">
#        <ul class="navbar-nav mr-auto">
#        </ul>
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id">
#           <i class="el el-home-alt">
#           </i>
#          </a>
#         </li>
#         <!-- <li class="nav-item">
#                                 <a class="nav-link" href="#!">About</a>
#                             </li> -->
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id/authors">
#           Author
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id/subjects">
#           Subjects
#          </a>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#           Affiliations
#          </a>
#          <div aria-labelledby="navbarDropdown" class="dropdown-menu">
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/affiliations">
#            Affiliations
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/departments">
#            Departments
#           </a>
#          </div>
#         </li>
#         <li class="nav-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#           Sources
#          </a>
#          <div aria-labelledby="navbarDropdown" class="dropdown-menu">
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/journals">
#            Journal
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/books">
#            Book
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/iprs">
#            IPR
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/researches">
#            Researches
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/comservices">
#            Comunity Services
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/scopus">
#            Scopus Documents
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/home/checkquartilescopus">
#            Check Quart. Scopus
#           </a>
#           <a class="dropdown-item" href="https://sinta.kemdikbud.go.id/google">
#            GS Documents
#           </a>
#          </div>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id/home/faq">
#           FAQ
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id/wcu">
#           WCU
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id/logins/registration">
#           Registration
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="https://sinta.kemdikbud.go.id/logins">
#           Login
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#     </div>
#     <div class="content">
#      <div class="content-box">
#       <div class="univ-profile">
#        <div class="bg-univ" style="background-image: url('https://sinta.kemdikbud.go.id/public/assets/img/bg-univ.jpg');">
#         <div class="univ-name">
#          <img alt="" class="img-fluid round-corner mb-4 univ-logo-main" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/univ-logo.png';" src="/authorverification/public/images/affiliations/2053.jpg"/>
#          <h3>
#           <a href="#!">
#            Universitas Muhammadiyah Malang
#           </a>
#          </h3>
#          <div class="meta-profile">
#           <span class="affil-abbrev mr-3">
#            <i class="zmdi zmdi-label mr-1">
#            </i>
#            UMM
#           </span>
#           <a class="affil-loc" href="#!">
#            <i class="el el-map-marker mr-1">
#            </i>
#            KOTA MALANG - JAWA TIMUR, ID
#           </a>
#           <span class="mr-3 d-none d-sm-block">
#           </span>
#           <a class="affil-code" href="#!">
#            <i class="el el-certificate mr-1">
#            </i>
#            ID : 2053
#            <i class="zmdi zmdi-code ml-2">
#            </i>
#            PDDIKTI's CODE : 071024
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="au-list-affil mt-3">
#        <div class="row added-info">
#         <div class="col-md-9 mb-3">
#          <i class="el el-chevron-right mr-2">
#          </i>
#          817 Authors in
#          <a href="https://sinta.kemdikbud.go.id/affiliations/departments/2053/071024">
#           65 Departments
#          </a>
#         </div>
#         <div class="col-md back-btn-profile">
#          <a class="btn btn-sm btn-light" href="https://sinta.kemdikbud.go.id/affiliations/profile/2053">
#           <i class="el el-chevron-left">
#           </i>
#           Back to profile
#          </a>
#         </div>
#        </div>
#        <div class="row mt-5">
#         <form class="col-md-8 mb-3">
#          <label class="small-lbl">
#           Search
#          </label>
#          <!-- <div class="input-group input-group-sm mb-3"> -->
#          <input aria-describedby="basic-addon2" aria-label="Search" class="form-control form-control-sm" name="q" placeholder="Search Authors..." type="text"/>
#          <!-- <div class="input-group-append"> -->
#          <!-- <span class="input-group-text" id="basic-addon2"> -->
#          <!-- <a data-toggle="tooltip" data-placement="left" title="Advanced search" href="#!"><i class="el el-cog"></i></a> -->
#          <!-- </span> -->
#          <!-- </div> -->
#          <!-- </div> -->
#         </form>
#         <form action="" class="form" method="POST">
#          <input name="page" type="hidden" value="1"/>
#          <label class="small-lbl">
#           Sort by
#          </label>
#          <select class="form-control form-control-sm custom-select form-control-block" id="sort" name="sort" style="padding-right: 30px;">
#           <option selected="" value="1">
#            Sinta Score 3Yr
#           </option>
#           <option value="2">
#            Sinta Score Overall
#           </option>
#           <option value="3">
#            Affil Score 3Yr
#           </option>
#           <option value="4">
#            Affil Score Overall
#           </option>
#           <option value="5">
#            Scopus H-index
#           </option>
#           <option value="6">
#            Google H-index
#           </option>
#          </select>
#         </form>
#        </div>
#        <nav aria-label="pagination-sample" class="mb-4 mt-2">
#         <ul class="pagination justify-content-center">
#          <li class="page-item disabled">
#           <a aria-disabled="true" class="page-link" href="?page=" tabindex="-1">
#            Previous
#           </a>
#          </li>
#          <li class="page-item active">
#           <a class="page-link" href="?page=1">
#            1
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=2">
#            2
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=3">
#            3
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=4">
#            4
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=5">
#            5
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=2">
#            Next
#           </a>
#          </li>
#         </ul>
#         <div class="text-center pagination-text">
#          <small>
#           Page 1 of 82 | Total Records 817
#          </small>
#         </div>
#        </nav>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=YaPYZnwAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/5991174">
#             DANA MARSETIYA UTAMA
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/151B5AE4-85B7-4B01-865A-9B4E5DC255A6">
#               <i class="el el-child mr-1">
#               </i>
#               Teknik Industri (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 5991174
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 15
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 25
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                1.100
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                2.719
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                1.100
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                2.719
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=yvohgFoAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/5977965">
#             ILYAS MASUDIN
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/151B5AE4-85B7-4B01-865A-9B4E5DC255A6">
#               <i class="el el-child mr-1">
#               </i>
#               Teknik Industri (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 5977965
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 17
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 25
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                987
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                3.128
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=3YBrj-MAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/6880111">
#             RANI DARMAYANTI
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="#!">
#               <i class="el el-child mr-1">
#               </i>
#               Unknown
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 6880111
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 0
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 62
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                960
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                2.641
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=CUBCCX8AAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/257540">
#             HUSAMAH
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/7460AD26-6962-4FD2-9E0E-5BC313F91F89">
#               <i class="el el-child mr-1">
#               </i>
#               Pendidikan Biologi (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 257540
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 11
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 31
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                850
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                3.167
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=nS4Nq4IAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/6813591">
#             ROY HENDROKO SETYOBUDI
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="#!">
#               <i class="el el-child mr-1">
#               </i>
#               Unknown
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 6813591
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 19
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 20
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                771
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                3.024
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=eZKmCK4AAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/6016076">
#             DIAN PALUPI RESTUPUTRI
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/151B5AE4-85B7-4B01-865A-9B4E5DC255A6">
#               <i class="el el-child mr-1">
#               </i>
#               Teknik Industri (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 6016076
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 11
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 19
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                753
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                1.793
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=ZNZhPXMAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/5992369">
#             SALAHUDIN
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/825EA81A-0CAA-4FB8-B96B-3F82572F44FC">
#               <i class="el el-child mr-1">
#               </i>
#               Ilmu Pemerintahan (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 5992369
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 8
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 19
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                751
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                2.152
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                751
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                2.152
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=MLz24y8AAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/6471157">
#             SHOLAHUDDIN AL-FATIH
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/13B8FBAB-6D39-4DB1-948B-33ED05F538B5">
#               <i class="el el-child mr-1">
#               </i>
#               Hukum (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 6471157
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 8
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 21
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                750
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                2.008
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                0
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=jbcXttsAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/6136049">
#             AHMAD FAUZI
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/7460AD26-6962-4FD2-9E0E-5BC313F91F89">
#               <i class="el el-child mr-1">
#               </i>
#               Pendidikan Biologi (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 6136049
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 12
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 21
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                732
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                1.825
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                732
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                1.825
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="au-item mt-3 mb-3 pb-5 pt-3">
#         <div class="row">
#          <div class="col-lg-2">
#           <img alt="avatar" class="img-thumbnail avatar" onerror="this.onerror=null;this.src='https://sinta.kemdikbud.go.id/public/assets/img/author-small.png';" src="https://scholar.google.co.id/citations?view_op=view_photo&amp;user=9FWJkpMAAAAJ&amp;citpid=1"/>
#          </div>
#          <div class="col-lg">
#           <div class="profile-name">
#            <a href="https://sinta.kemdikbud.go.id/authors/profile/6720053">
#             ALI ROZIQIN
#            </a>
#            <i class="el el-ok-sign text-success ml-2">
#            </i>
#           </div>
#           <div class="row">
#            <div class="col-lg">
#             <div class="profile-dept">
#              <a href="https://sinta.kemdikbud.go.id/departments/profile/2053/6399D77D-8C55-4DFA-80F8-70027523099E/825EA81A-0CAA-4FB8-B96B-3F82572F44FC">
#               <i class="el el-child mr-1">
#               </i>
#               Ilmu Pemerintahan (S1)
#              </a>
#             </div>
#             <div class="profile-id">
#              <i class="el el-user mr-1">
#              </i>
#              ID : 6720053
#              <span class="fi fi-id ml-1">
#              </span>
#             </div>
#             <div class="profile-hindex">
#              <span class="profile-id text-warning">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               Scopus H-Index : 6
#              </span>
#              <span class="profile-id text-success ml-3">
#               <i class="zmdi zmdi-chart-donut mr-1">
#               </i>
#               GS H-Index : 18
#              </span>
#             </div>
#            </div>
#            <div class="col-lg">
#             <div class="row">
#              <div class="col">
#               <div class="stat-num text-center">
#                703
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                1.422
#               </div>
#               <div class="stat-text text-center">
#                SINTA Score
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                703
#               </div>
#               <div class="stat-text text-center">
#                Affil Score 3Yr
#               </div>
#              </div>
#              <div class="col">
#               <div class="stat-num text-center">
#                1.422
#               </div>
#               <div class="stat-text text-center">
#                Affil Score
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <nav aria-label="pagination-sample" class="mb-4 mt-2">
#         <ul class="pagination justify-content-center">
#          <li class="page-item disabled">
#           <a aria-disabled="true" class="page-link" href="?page=" tabindex="-1">
#            Previous
#           </a>
#          </li>
#          <li class="page-item active">
#           <a class="page-link" href="?page=1">
#            1
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=2">
#            2
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=3">
#            3
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=4">
#            4
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=5">
#            5
#           </a>
#          </li>
#          <li class="page-item">
#           <a class="page-link" href="?page=2">
#            Next
#           </a>
#          </li>
#         </ul>
#         <div class="text-center pagination-text">
#          <small>
#           Page 1 of 82 | Total Records 817
#          </small>
#         </div>
#        </nav>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="col-md-4 d-none d-md-block d-lg-block d-xl-block decor animate__animated animate__slideInRight">
#     <div class="side-top row">
#      <div class="col-md-4">
#       Get More with SINTA Insight
#      </div>
#      <div class="col-md-8">
#       <a class="btn btn-warning btn-block btn-md" href="https://sinta.kemdikbud.go.id/insight" id="" name="" role="button">
#        Go to Insight
#       </a>
#      </div>
#     </div>
#     <div class="side-content">
#      <div class="row stat-card mb-4">
#       <div class="col">
#        <div class="card bg-card-default">
#         <div class="card-body">
#          <div class="stat-num">
#           817
#          </div>
#          <div class="stat-text">
#           Total Authors
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col">
#        <div class="card bg-card-red">
#         <div class="card-body">
#          <div class="stat-arrow">
#           <a href="https://sinta.kemdikbud.go.id/affiliations/departments/2053/071024">
#            <i class="el el-circle-arrow-right">
#            </i>
#           </a>
#          </div>
#          <div class="stat-num">
#           65
#          </div>
#          <div class="stat-text">
#           Departments
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row stat-card mb-4">
#       <div class="col">
#        <div class="card bg-card-orange">
#         <div class="card-body">
#          <h5 class="text-center">
#           Academic Rank
#          </h5>
#          <div id="academic-grade-pie" style="height: 225px;">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- JavaScript -->
#   <!-- jQuery first, then others -->
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/jquery-3.5.1.min.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/popper.min.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/bootstrap.min.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/select2.full.min.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/morphext.min.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/echarts/dist/echarts-en.min.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/js/echarts/dist/theme/macarons.js" type="text/javascript">
#   </script>
#   <!-- <script src="https://sinta.kemdikbud.go.id/public/assets/js/jquery.autocomplete.js" crossorigin="anonymous"></script>     -->
#   <script crossorigin="anonymous" src="https://sinta.kemdikbud.go.id/public/assets/plugin/autocomplete/jquery.autocomplete.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="https://sinta.kemdikbud.go.id/public/assets/plugin/datamaps/d3.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="https://sinta.kemdikbud.go.id/public/assets/plugin/datamaps/topojson.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="https://sinta.kemdikbud.go.id/public/assets/plugin/datamaps/datamaps.idn.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="https://sinta.kemdikbud.go.id/public/assets/plugin/chartjs/chart.js" type="text/javascript">
#   </script>
#   <script src="https://unpkg.com/vis-network/standalone/umd/vis-network.min.js" type="text/javascript">
#   </script>
#   <script src="//unpkg.com/bootstrap-select@1.12.4/dist/js/bootstrap-select.min.js">
#   </script>
#   <script src="//unpkg.com/bootstrap-select-country@4.0.0/dist/js/bootstrap-select-country.min.js">
#   </script>
#   <script src="https://cdn.jsdelivr.net/npm/select2@4.1.0-rc.0/dist/js/select2.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.9.0/js/bootstrap-datepicker.min.js">
#   </script>
#   <script>
#    setTimeout(function() {
#             $('#alert-notif').fadeOut('fast');
#         }, 3000);
#
#         function show_faq(id){
#             $('#' + id).slideToggle();
#         }
#
#         $(function () {
#             $('[data-toggle="tooltip"]').tooltip()
#         });
#
#         $('.countrypicker').countrypicker();
#   </script>
#   <script>
#    $(document).ready(function(){
#             $(function () {
#                 $('.datepicker-year').datepicker({
#                     autoclose: true,
#                     endDate: new Date(),
#                     format: 'yyyy',
#                     viewMode: "years",
#                     minViewMode: "years"
#                 });
#             });
#
#             $(function () {
#                 $('.datepicker-date').datepicker({
#                     todayHighlight: true,
#                     endDate: new Date(),
#                     autoclose: true,
#                     format: 'yyyy-mm-dd',
#                     maxDate: '0'
#                 });
#             });
#         });
#   </script>
#   <script>
#    $(function () {
#             $('[data-toggle="popover"]').popover()
#         });
#
#         $('.popover-dismiss').popover({
#             trigger: 'focus'
#         })
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
#         $('#sort').on('change', function() {
#             this.form.submit();
#         });
#     });
#   </script>
#   <script>
#    $(document).ready(function() {
#         $(".select2").select2({
#             minimumResultsForSearch: -1
#         });
#         $('[data-toggle="tooltip"]').tooltip()
#     });
#
#             // based on prepared DOM, initialize echarts instance
#         var quartilePie = echarts.init(document.getElementById('academic-grade-pie'), 'macarons');
#         optionQ = {
#             tooltip: {
#                 trigger: 'item',
#                 formatter: '{a} <br/>{b}: {c} ({d}%)'
#             },
#             legend: {
#                 show: false,
#                 orient: 'vertical',
#                 left: 10,
#                 top: 34,
#                 data: [
#                                             'Lektor',
#                                             'Lektor Kepala',
#                                             'Asisten Ahli',
#                                             'Profesor',
#                                             'Tenaga Pengajar',
#                                             'Unknown',
#                                     ]
#             },
#             grid: {
#                 left: 0,
#                 top: 0,
#                 right: 0,
#                 bottom: 0,
#             },
#             series: [{
#                 name: 'Academic Grade',
#                 type: 'pie',
#                 radius: ['50%', '80%'],
#                 avoidLabelOverlap: false,
#                 center: ['50%', '50%'],
#                 itemStyle: {
#                     normal: {
#                         label: {
#                             show: true,
#                             position: 'outside',
#                             formatter: function(params) {
#                                 console.log(params);
#                                 return params.name + " : " + params.value;
#                             },
#                             textStyle: {
#                                 fontSize: 12
#                             }
#                         },
#                         labelLine: {
#                             show: true
#                         }
#                     },
#                 },
#                 emphasis: {
#                     label: {
#                         show: true,
#                         fontSize: '11',
#                     }
#                 },
#                 labelLine: {
#                     show: false
#                 },
#                 data: [
#                                             {
#                             value: 270,
#                             name: 'Lektor',
#                         },
#                                             {
#                             value: 115,
#                             name: 'Lektor Kepala',
#                         },
#                                             {
#                             value: 219,
#                             name: 'Asisten Ahli',
#                         },
#                                             {
#                             value: 58,
#                             name: 'Profesor',
#                         },
#                                             {
#                             value: 0,
#                             name: 'Tenaga Pengajar',
#                         },
#                                             {
#                             value: 155,
#                             name: 'Unknown',
#                         },
#                                     ]
#             }]
#         };
#         quartilePie.setOption(optionQ);
#   </script>
#  </body>
# </html>

# %%
def scrape_page(page_number):
    """
    Fungsi untuk melakukan scraping data penulis dari halaman tertentu di SINTA.

    Parameter:
    - page_number: Nomor halaman yang akan diambil datanya.

    Return:
    - List berisi data penulis dari halaman yang diambil.
    """
    url = f"https://sinta.kemdikbud.go.id/affiliations/authors/2053?page={page_number}" # anda bisa mengubah kampus dengan menganti kode angka pada tautan setelah authors
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    authors_data = []  # List untuk menyimpan data penulis

    # Mencari semua item penulis di halaman
    for item in soup.select('.au-item'):
        name = item.select_one('.profile-name a').text.strip()  # Mengambil nama penulis
        dept = item.select_one('.profile-dept').text.strip()  # Mengambil nama departemen
        stats = item.select('.stat-num.text-center')  # Mengambil data skor SINTA

        # Menyimpan skor berdasarkan urutan tampilan di website
        sinta_score_3yr = stats[0].text.strip()
        sinta_score = stats[1].text.strip()
        affil_score_3yr = stats[2].text.strip()
        affil_score = stats[3].text.strip()

        # Menambahkan data ke dalam list
        authors_data.append({
            'name': name,
            'dept': dept,
            'sinta_score_3yr': sinta_score_3yr,
            'sinta_score': sinta_score,
            'affil_score_3yr': affil_score_3yr,
            'affil_score': affil_score
        })

    return authors_data  # Mengembalikan data yang telah dikumpulkan

# %%
def main(max_page=20):
    """
    Fungsi utama untuk menjalankan proses scraping hingga batas halaman tertentu.

    Parameters:
    max_page (int): Jumlah maksimal halaman yang akan di-scrape.
    """
    all_authors = []  # List untuk menyimpan semua data penulis
    page = 1  # Memulai dari halaman pertama

    while page <= max_page:  # Loop hanya sampai batas halaman yang ditentukan
        print(f"Scraping halaman {page}...")  # Menampilkan informasi proses scraping
        authors = scrape_page(page)  # Scraping data dari halaman saat ini
        if not authors:  # Jika tidak ada data, hentikan proses
            break
        all_authors.extend(authors)  # Menambahkan data ke dalam list utama
        page += 1  # Pindah ke halaman berikutnya

        # Memberikan jeda 10 detik sebelum berpindah ke halaman berikutnya
        if page <= max_page:  # Hanya tunggu jika masih ada halaman berikutnya
            time.sleep(10)

    # Membuat tabel untuk menampilkan data
    table = PrettyTable()
    table.field_names = ["Nama Penulis", "Departemen", "SINTA Score 3Yr", "SINTA Score", "Affil Score 3Yr", "Affil Score"]

    # Memasukkan data penulis ke dalam tabel
    for author in all_authors:
        table.add_row([author['name'], author['dept'], author['sinta_score_3yr'], author['sinta_score'], author['affil_score_3yr'], author['affil_score']])

    # Mencetak tabel ke terminal
    print(table)

    # Menyimpan data ke dalam file CSV
    df = pd.DataFrame(all_authors)  # Mengubah list ke dataframe pandas
    df.to_csv("sinta_authors.csv", index=False)  # Simpan sebagai CSV tanpa index

    print("Scraping selesai! Data disimpan di 'sinta_authors.csv'.")

if __name__ == '__main__':
    main(max_page=20)  # Ganti angka sesuai jumlah halaman yang ingin diambil
# Out:
# Scraping halaman 1...
# Scraping halaman 2...
# Scraping halaman 3...
# Scraping halaman 4...
# Scraping halaman 5...
# Scraping halaman 6...
# Scraping halaman 7...
# Scraping halaman 8...
# Scraping halaman 9...
# Scraping halaman 10...
# Scraping halaman 11...
# Scraping halaman 12...
# Scraping halaman 13...
# Scraping halaman 14...
# Scraping halaman 15...
# Scraping halaman 16...
# Scraping halaman 17...
# Scraping halaman 18...
# Scraping halaman 19...
# Scraping halaman 20...
# +----------------------------------+-----------------------------------------------+-----------------+-------------+-----------------+-------------+
# |           Nama Penulis           |                   Departemen                  | SINTA Score 3Yr | SINTA Score | Affil Score 3Yr | Affil Score |
# +----------------------------------+-----------------------------------------------+-----------------+-------------+-----------------+-------------+
# |       DANA MARSETIYA UTAMA       |              Teknik Industri (S1)             |      1.100      |    2.719    |      1.100      |    2.719    |
# |          ILYAS MASUDIN           |              Teknik Industri (S1)             |       987       |    3.128    |        0        |      0      |
# |         RANI DARMAYANTI          |                    Unknown                    |       960       |    2.641    |        0        |      0      |
# |             HUSAMAH              |            Pendidikan Biologi (S1)            |       850       |    3.167    |        0        |      0      |
# |      ROY HENDROKO SETYOBUDI      |                    Unknown                    |       771       |    3.024    |        0        |      0      |
# |      DIAN PALUPI RESTUPUTRI      |              Teknik Industri (S1)             |       753       |    1.793    |        0        |      0      |
# |            SALAHUDIN             |             Ilmu Pemerintahan (S1)            |       751       |    2.152    |       751       |    2.152    |
# |       SHOLAHUDDIN AL-FATIH       |                   Hukum (S1)                  |       750       |    2.008    |        0        |      0      |
# |           AHMAD FAUZI            |            Pendidikan Biologi (S1)            |       732       |    1.825    |       732       |    1.825    |
# |           ALI ROZIQIN            |             Ilmu Pemerintahan (S1)            |       703       |    1.422    |       703       |    1.422    |
# |       YUS MOCHAMAD CHOLILY       |           Pendidikan Matematika (S2)          |       634       |    2.073    |        0        |      0      |
# |          AKHSANUL IN'AM          |                Pendidikan (S3)                |       624       |    2.452    |       624       |    2.452    |
# |              DAMAT               |             Teknologi Pangan (S1)             |       614       |    1.346    |        0        |      0      |
# |            LUD WALUYO            |            Pendidikan Biologi (S2)            |       604       |    2.030    |       604       |    2.030    |
# |       YOYOK BEKTI PRASETYO       |             Ilmu Keperawatan (S1)             |       582       |    1.359    |        0        |      0      |
# |           YUFIS AZHAR            |                Informatika (S1)               |       517       |    1.386    |        0        |      0      |
# |           ADI SUTANTO            |                Peternakan (S1)                |       515       |    1.008    |       515       |    1.008    |
# |   SRI SUNARINGSIH IKA WARDOJO    |                Fisioterapi (S1)               |       496       |     853     |        0        |      0      |
# |           LILI ZALIZAR           |              Ilmu Pertanian (S3)              |       482       |    1.102    |       482       |    1.102    |
# |         AGUS EKO MINARNO         |                Informatika (S1)               |       475       |    1.493    |       475       |    1.493    |
# |         RAHAYU RELAWATI          |                Agribisnis (S1)                |       472       |     940     |        0        |      0      |
# |       JABAL TARIK IBRAHIM        |                 Sosiologi (S2)                |       467       |    1.261    |        0        |      0      |
# |        ERFAN DANI SEPTIA         |               Agroteknologi (S1)              |       457       |     722     |       457       |     722     |
# |             SUGIARTI             |        Pendidikan Bahasa Indonesia (S1)       |       455       |    1.941    |        0        |      0      |
# |          MOH. NURHAKIM           |          Pendidikan Agama Islam (S3)          |       447       |    1.215    |       447       |    1.215    |
# |          DINA MARDIANA           |          Pendidikan Agama Islam (S2)          |       435       |    1.000    |       435       |    1.000    |
# |  Achmad Fauzan Hery Soegiharto   |               Teknik Mesin (S1)               |       431       |     857     |       431       |     857     |
# |             BAIDURI              |           Pendidikan Matematika (S2)          |       427       |    1.059    |        0        |      0      |
# |           NOOR HARINI            |             Teknologi Pangan (S1)             |       425       |     856     |       425       |     856     |
# |        TONNY DIAN EFFENDI        |          Hubungan Internasional (S1)          |       420       |     801     |        0        |      0      |
# |            ALI IKHWAN            |               Agroteknologi (S1)              |       415       |     945     |        0        |      0      |
# |           OMAN SUKMANA           |           Kesejahteraan Sosial (S1)           |       415       |     883     |       415       |     883     |
# |             UMIARSO              |          Pendidikan Agama Islam (S2)          |       414       |    1.457    |       414       |    1.457    |
# |        RR EKO SUSETYARINI        |            Pendidikan Biologi (S1)            |       411       |    1.291    |       411       |    1.291    |
# |          YUNI PANTIWATI          |            Pendidikan Biologi (S2)            |       408       |    1.398    |       408       |    1.398    |
# |       BAMBANG YUDI ARIADI        |                Agribisnis (S1)                |       405       |     651     |        0        |      0      |
# |      SRI BUDI CANTIKA YULI       |          Perbankan Dan Keuangan (D3)          |       403       |    1.081    |        0        |      0      |
# |           WAHYU WIDODO           |                Peternakan (S1)                |       403       |    1.211    |        0        |      0      |
# |          GONDA YUMITRO           |          Hubungan Internasional (S1)          |       402       |     912     |       402       |     912     |
# |       IRADHAD TAQWA SIHIDI       |             Ilmu Pemerintahan (S1)            |       400       |    1.064    |        0        |      0      |
# |          RAKHMAD ROSADI          |    Pendidikan Profesi Fisioterapi (Profesi)   |       399       |     617     |        0        |      0      |
# |        M. SYAPRIN ZAHIDI         |          Hubungan Internasional (S1)          |       394       |    1.099    |       394       |    1.099    |
# |        EGGY FAJAR ANDALAS        |        Pendidikan Bahasa Indonesia (S1)       |       387       |    1.348    |       387       |    1.348    |
# |        MOH MAHFUD EFFENDI        |           Pendidikan Matematika (S2)          |       384       |     866     |       384       |     866     |
# | AGUNG PRASETYO NUGROHO WICAKSONO |                 Akuntansi (S1)                |       381       |     757     |       381       |     757     |
# |       ANNISA KESY GARSIDE        |           Profesi Insinyur (Profesi)          |       379       |    1.172    |       379       |    1.172    |
# |           NUR MELIZZA            |             Ilmu Keperawatan (S1)             |       376       |     738     |        0        |      0      |
# |          M. ZUL MAZWAN           |                Agribisnis (S1)                |       376       |     600     |       376       |     600     |
# |      GALIH WASIS WICAKSONO       |                Informatika (S1)               |       375       |     792     |        0        |      0      |
# |          ERNY ISHARTATI          |                Agribisnis (S2)                |       373       |     947     |        0        |      0      |
# |       MOHAMMAD SYAIFUDDIN        |                 Pedagogi (S2)                 |       372       |     863     |       372       |     863     |
# |         NAZARUDDIN MALIK         |            Ekonomi Pembangunan (S1)           |       365       |     880     |       365       |     880     |
# |          ARTI PRIHATINI          |        Pendidikan Bahasa Indonesia (S1)       |       363       |     619     |        0        |      0      |
# |         IIS SITI AISYAH          |               Teknik Mesin (S1)               |       359       |    1.023    |        0        |      0      |
# |          SONI ANDRIAWAN          |                Akuakultur (S1)                |       357       |     464     |        0        |      0      |
# |       ANGGRAINI DWI KURNIA       |                Keperawatan (D3)               |       355       |     803     |       355       |     803     |
# |        NUR PUTRI HIDAYAH         |                   Hukum (S1)                  |       352       |     729     |        0        |      0      |
# |     NAJAMUDDIN KHAIRUR RIJAL     |          Hubungan Internasional (S1)          |       352       |     845     |       352       |     845     |
# |           IDAH ZUHROH            |            Ekonomi Pembangunan (S1)           |       352       |     917     |        0        |      0      |
# |      NUR LAILATUL MASRUROH       |             Ilmu Keperawatan (S1)             |       349       |     770     |        0        |      0      |
# |           ANIEK IRIANY           |               Agroteknologi (S1)              |       341       |     740     |       341       |     740     |
# |             TOBRONI              |          Pendidikan Agama Islam (S3)          |       341       |    1.272    |        0        |      0      |
# |      VRITTA AMROINI WAHYUDI      |             Teknologi Pangan (S1)             |       340       |     608     |        0        |      0      |
# |       RIBUT WAHYU ERIYANTI       |                Pendidikan (S3)                |       339       |     849     |       339       |     849     |
# |          NI'MATUZAHROH           |                 Psikologi (S2)                |       338       |    1.634    |       338       |    1.634    |
# |       DESIANA NURIZA PUTRI       |             Teknologi Pangan (S1)             |       336       |     739     |        0        |      0      |
# |          ELLY PURWANTI           |            Pendidikan Biologi (S2)            |       335       |     886     |        0        |      0      |
# |           ZAINUL ANWAR           |     Pendidikan Profesi Psikologi (Profesi)    |       334       |     823     |       334       |     823     |
# |   ALFIANI ATHMA PUTRI ROSYADI    |           Pendidikan Matematika (S2)          |       334       |     790     |       334       |     790     |
# |    FEBRI ENDRA BUDI SETYAWAN     |                Kedokteran (S1)                |       325       |    1.250    |        0        |      0      |
# |            DWI IRAWAN            |                 Akuntansi (S1)                |       322       |     601     |        0        |      0      |
# |        SHANTY KUSUMA DEWI        |              Teknik Industri (S1)             |       317       |     894     |       317       |     894     |
# |           HANIF AKHTAR           |                 Psikologi (S1)                |       313       |     703     |       313       |     703     |
# |       TUTUT INDRIA PERMANA       |            Pendidikan Biologi (S1)            |       310       |     634     |       310       |     634     |
# |      ANITA FARADILLA RAHIM       |                Fisioterapi (S1)               |       310       |     570     |       310       |     570     |
# |       CHALIMATUZ SA'DIYAH        |                 Manajemen (S1)                |       309       |     538     |        0        |      0      |
# |       WAHYU ANDHYKA KUSUMA       |                Informatika (S1)               |       307       |    1.176    |        0        |      0      |
# |        MOH. MIRZA NURYADY        |            Pendidikan Biologi (S1)            |       306       |     621     |       306       |     621     |
# |         ELFI ANIS SAATI          |             Teknologi Pangan (S1)             |       305       |    1.114    |        0        |      0      |
# |        AZHAR ADI DARMAWAN        |               Teknik Sipil (S1)               |       305       |     712     |       305       |     712     |
# |           ALI MOKHTAR            |           Profesi Insinyur (Profesi)          |       304       |     651     |       304       |     651     |
# |             MURDIONO             |          Pendidikan Bahasa Arab (S1)          |       304       |     579     |       304       |     579     |
# |   CHRISTIAN SRI KUSUMA ADITYA    |                Informatika (S1)               |       304       |     533     |       304       |     533     |
# |           JOKO WIDODO            |                Pendidikan (S3)                |       302       |     658     |       302       |     658     |
# |            ERNA YAYUK            |       Pendidikan Profesi Guru (Profesi)       |       296       |     806     |       296       |     806     |
# |            ZULFATMAN             |              Teknik Elektro (S1)              |       296       |    1.773    |       296       |    1.773    |
# |  VINA SALVIANA DARVINA SOEDARWO  |                 Sosiologi (S3)                |       293       |     682     |        0        |      0      |
# |        IKHLASUL AMALLYNDA        |              Teknik Industri (S1)             |       292       |     581     |       292       |     581     |
# |       DAROE ISWATININGSIH        |        Pendidikan Bahasa Indonesia (S1)       |       289       |     759     |        0        |      0      |
# |           ARY BAKHTIAR           |                Agribisnis (S1)                |       288       |     667     |       288       |     667     |
# |          ANIEK RUMIJATI          |                 Manajemen (S2)                |       288       |     483     |       288       |     483     |
# |           NUR HAYATIN            |                Informatika (S1)               |       286       |     861     |       286       |     861     |
# |              FARIDI              |          Pendidikan Agama Islam (S3)          |       285       |     760     |        0        |      0      |
# |           SYARIF HUSEN           |               Agroteknologi (S1)              |       285       |     719     |        0        |      0      |
# |           SRI WAHYUNI            |            Pendidikan Biologi (S1)            |       284       |     978     |        0        |      0      |
# |            ZAMAH SARI            |                Informatika (S1)               |       284       |     831     |        0        |      0      |
# |           SITI INGANAH           |           Pendidikan Matematika (S2)          |       283       |     633     |        0        |      0      |
# |             WIDAYAT              |                 Manajemen (S1)                |       282       |     746     |        0        |      0      |
# |    OLLYVIA FREESKA DWI MARTA     |             Ilmu Keperawatan (S1)             |       281       |     363     |        0        |      0      |
# |    FAUZI DWI SETIAWAN SUMADI     |                Informatika (S1)               |       278       |     655     |        0        |      0      |
# |       CEKLI SETYA PRATIWI        |                   Hukum (S1)                  |       278       |     744     |       278       |     744     |
# |           YUDA MUNARKO           |                Informatika (S1)               |       275       |     737     |       275       |     737     |
# |          ASEP NURJAMAN           |             Ilmu Pemerintahan (S1)            |       273       |     772     |       273       |     772     |
# |       KUKUH DWI KURNIAWAN        |                   Hukum (S1)                  |       272       |     479     |        0        |      0      |
# |       ROSE FITRIA LUTFIANA       | Pendidikan Pancasila Dan Kewarganegaraan (S1) |       271       |     438     |        0        |      0      |
# |           ARIS WINAYA            |              Ilmu Pertanian (S3)              |       269       |     855     |        0        |      0      |
# |          ARDIK PRAHARJO          |                 Manajemen (S1)                |       268       |     480     |       268       |     480     |
# | MUHAMMAD SRI WAHYUDI SULISWANTO  |            Ekonomi Pembangunan (S1)           |       266       |     867     |       266       |     867     |
# |           RIRIN HARINI           |             Profesi Ners (Profesi)            |       266       |     450     |        0        |      0      |
# |        IKA RATNA HIDAYATI        |     Pendidikan Profesi Apoteker (Profesi)     |       265       |     474     |        0        |      0      |
# |   NUNGKI MARLIAN YULIADARWATI    |    Pendidikan Profesi Fisioterapi (Profesi)   |       264       |     544     |        0        |      0      |
# |          SYAMSUL ARIFIN          |          Pendidikan Agama Islam (S3)          |       264       |    1.015    |        0        |      0      |
# |        NOVENDRA SETYAWAN         |              Teknik Elektro (S1)              |       262       |     639     |       262       |     639     |
# |          ARIS SOELISTYO          |            Ekonomi Pembangunan (S1)           |       262       |     588     |        0        |      0      |
# |             NUR AINI             |             Profesi Ners (Profesi)            |       260       |     635     |        0        |      0      |
# |     MUHAMMAD KHOIRUL FUDDIN      |            Ekonomi Pembangunan (S1)           |       259       |     399     |       259       |     399     |
# |             ROMELAH              |          Pendidikan Agama Islam (S2)          |       259       |     754     |        0        |      0      |
# |          ILYAS NURYASIN          |                Informatika (S1)               |       258       |     690     |        0        |      0      |
# |      GITA INDAH MARTHASARI       |                Informatika (S1)               |       256       |     713     |       256       |     713     |
# |              SUTAWI              |                Agribisnis (S2)                |       254       |     656     |       254       |     656     |
# |         DIANI FATMAWATI          |            Pendidikan Biologi (S1)            |       254       |     659     |        0        |      0      |
# |         DRIANA LENIWATI          |                 Akuntansi (S2)                |       252       |     407     |        0        |      0      |
# |         MERINDA LESTANDY         |              Teknik Elektro (S1)              |       250       |     466     |       250       |     466     |
# |       NURUL AINI RAHMAWATI       |    Pendidikan Profesi Fisioterapi (Profesi)   |       250       |     398     |        0        |      0      |
# |          SIDIK SUNARYO           |                   Hukum (S2)                  |       248       |     573     |        0        |      0      |
# |          AHMAD WAHYUDI           |              Ilmu Pertanian (S3)              |       248       |    1.376    |       248       |    1.376    |
# |          MEDDY SETIAWAN          |      Pendidikan Profesi Dokter (Profesi)      |       246       |     588     |       246       |     588     |
# |           AULIA ZAKIA            |               Agroteknologi (S1)              |       246       |     371     |        0        |      0      |
# |         INDAH PRIHARTINI         |              Ilmu Pertanian (S3)              |       245       |     733     |        0        |      0      |
# |         LILIS SETYOWATI          |                Keperawatan (D3)               |       244       |     589     |       244       |     589     |
# |           SYAMSUL HADI           |              Bisnis Properti (D4)             |       243       |     701     |        0        |      0      |
# |              FAUZAN              |        Pendidikan Bahasa Indonesia (S2)       |       243       |     493     |        0        |      0      |
# |          GIGIT MUJIANTO          |        Pendidikan Bahasa Indonesia (S1)       |       243       |     742     |        0        |      0      |
# |          HENIK SUKORINI          |               Agroteknologi (S1)              |       242       |     500     |        0        |      0      |
# |       TRI SULISTYANINGSIH        |                 Sosiologi (S3)                |       242       |     668     |       242       |     668     |
# |         EVI DWI WAHYUNI          |                Informatika (S1)               |       240       |     568     |        0        |      0      |
# |         TITIEK AMBARWATI         |          Perbankan Dan Keuangan (D3)          |       239       |     394     |        0        |      0      |
# |      FENDY HARDIAN PERMANA       |            Pendidikan Biologi (S1)            |       238       |     676     |       238       |     676     |
# |         DWI POEDJIASTUTI         |                Pendidikan (S3)                |       236       |     804     |        0        |      0      |
# |        HENNY DWI SUSANTI         |             Ilmu Keperawatan (S1)             |       235       |     423     |        0        |      0      |
# |        RAFIKA RABBA FARAH        |         Pendidikan Bahasa Inggris (S1)        |       234       |     488     |        0        |      0      |
# |        TUTIK SULISTYOWATI        |                 Sosiologi (S3)                |       234       |     519     |        0        |      0      |
# |       ABDURROHMAN MUZAKKI        |       Pendidikan Guru Sekolah Dasar (S1)      |       234       |     411     |       234       |     411     |
# |           AMRUL FARUQ            |              Teknik Elektro (S1)              |       233       |     895     |       233       |     895     |
# |          MUHAMMAD KAMIL          |             Ilmu Pemerintahan (S1)            |       233       |     966     |       233       |     966     |
# |     BETI ISTANTI SUWANDAYANI     |       Pendidikan Guru Sekolah Dasar (S1)      |       232       |    1.004    |       232       |    1.004    |
# |             SUNARDI              |             Profesi Ners (Profesi)            |       232       |     776     |        0        |      0      |
# |      WEHANDAKA PANCAPALAGA       |                Peternakan (S1)                |       230       |     725     |        0        |      0      |
# |           ABDUL HARIS            |          Pendidikan Bahasa Arab (S1)          |       230       |     670     |       230       |     670     |
# |          ANIS ZUBAIDAH           |                Akuakultur (S1)                |       229       |     560     |       229       |     560     |
# |        PURWATI ANGGRAINI         |        Pendidikan Bahasa Indonesia (S1)       |       228       |     665     |        0        |      0      |
# |           ALI MULTAZAM           |                Fisioterapi (S1)               |       228       |     431     |       228       |     431     |
# |    DYAH WOROWIRASTRI EKOWATI     |       Pendidikan Guru Sekolah Dasar (S1)      |       226       |     977     |        0        |      0      |
# |             HARIYADI             |                Akuakultur (S1)                |       226       |     563     |        0        |      0      |
# |            MAFTUCHAH             |              Ilmu Pertanian (S3)              |       226       |    1.387    |       226       |    1.387    |
# |           TYAS DEVIANA           |       Pendidikan Guru Sekolah Dasar (S1)      |       226       |     521     |       226       |     521     |
# |      HANIF ALAMUDIN MANSHUR      |             Teknologi Pangan (S1)             |       225       |     338     |        0        |      0      |
# |     ACH. APRIYANTO ROMADHAN      |             Ilmu Pemerintahan (S1)            |       224       |     459     |       224       |     459     |
# |       SITI KHOIRULI UMMAH        |           Pendidikan Matematika (S1)          |       224       |     744     |        0        |      0      |
# |         BUSTANOL ARIFIN          |       Pendidikan Guru Sekolah Dasar (S1)      |       224       |     745     |        0        |      0      |
# |       TRI WAHYU OKTAVENDI        |                 Akuntansi (S1)                |       222       |     437     |        0        |      0      |
# |     KHUSNUL ROFIDA NOVIANTI      |                 Manajemen (S1)                |       222       |     713     |        0        |      0      |
# |          AGUS ZAINUDIN           |               Agroteknologi (S1)              |       221       |     877     |       221       |     877     |
# |        FIEN ZULFIKARIJAH         |                 Manajemen (S2)                |       221       |     593     |        0        |      0      |
# |         DWI PRIYO UTOMO          |                Pendidikan (S3)                |       221       |     891     |        0        |      0      |
# |         HARDIANTO WIBOWO         |                Informatika (S1)               |       221       |     665     |        0        |      0      |
# |         BAMBANG WIDAGDO          |                 Manajemen (S1)                |       219       |     640     |        0        |      0      |
# |         M NURUL HUMAIDI          |          Pendidikan Agama Islam (S2)          |       219       |     290     |       219       |     290     |
# |        TRISAKTI HANDAYANI        |       Pendidikan Profesi Guru (Profesi)       |       218       |     751     |        0        |      0      |
# |          ARINA RESTIAN           |       Pendidikan Profesi Guru (Profesi)       |       218       |     829     |       218       |     829     |
# |        DYAH ROESWITAWATI         |               Agroteknologi (S1)              |       218       |     548     |        0        |      0      |
# |       RIZKA NOVIA ATMADANI       |     Pendidikan Profesi Apoteker (Profesi)     |       217       |     464     |       217       |     464     |
# |              KHOZIN              |          Pendidikan Agama Islam (S3)          |       216       |     446     |        0        |      0      |
# |        FITRIA ESFANDIARI         |                   Hukum (S1)                  |       216       |     335     |        0        |      0      |
# |    NANDY AGUSTIN SYAKAROFATH     |                 Psikologi (S1)                |       216       |     484     |       216       |     484     |
# |             SUKARDI              |             Teknologi Pangan (S1)             |       215       |     600     |        0        |      0      |
# |             SUDARMAN             |               Teknik Mesin (S1)               |       214       |     307     |        0        |      0      |
# |          BAYU PRASTOWO           |    Pendidikan Profesi Fisioterapi (Profesi)   |       214       |     486     |        0        |      0      |
# |       ANDINUSA RAHMANDHIKA       |               Teknik Mesin (S1)               |       214       |     285     |       214       |     285     |
# |          MASIYAH KHOLMI          |                 Akuntansi (S2)                |       213       |     788     |       213       |     788     |
# |       DIMAS SONDANG IRAWAN       |                Fisioterapi (S1)               |       213       |     388     |        0        |      0      |
# |         ZUKHRUFURROHMAH          |           Pendidikan Matematika (S1)          |       212       |     473     |        0        |      0      |
# |             WARKOYO              |             Teknologi Pangan (S1)             |       211       |     538     |        0        |      0      |
# |           AINUR ROFIEQ           |            Pendidikan Biologi (S2)            |       211       |     869     |       211       |     869     |
# |     ZIDNI IMANURROHMAH LUBIS     |                Fisioterapi (S1)               |       210       |     360     |        0        |      0      |
# |            IIN HINDUN            |       Pendidikan Profesi Guru (Profesi)       |       209       |     659     |        0        |      0      |
# |       ERMA WAHYU MASHFUFA        |             Ilmu Keperawatan (S1)             |       207       |     381     |        0        |      0      |
# |     ADITYA DWI PUTRA BHAKTI      |              Ilmu Komunikasi (S1)             |       207       |     423     |       207       |     423     |
# |       GITA SEKAR PRIHANTI        |                Kedokteran (S1)                |       206       |     838     |        0        |      0      |
# |         NAFIK MUTHOHIRIN         |          Pendidikan Agama Islam (S1)          |       206       |     539     |       206       |     539     |
# |       BELINDA DEWI REGINA        |       Pendidikan Guru Sekolah Dasar (S1)      |       204       |     507     |        0        |      0      |
# |       GALIT GATUT PRAKOSA        |                 Kehutanan (S1)                |       203       |     319     |        0        |      0      |
# |           ADI PRASETYO           |                 Akuntansi (S1)                |       202       |     596     |       202       |     596     |
# |      SETYO WAHYU SULISTYONO      |            Ekonomi Pembangunan (S1)           |       202       |     337     |        0        |      0      |
# |          WILDAN SUHARSO          |                Informatika (S1)               |       202       |     748     |        0        |      0      |
# |        THOMY EKO SAPUTRO         |              Teknik Industri (S1)             |       201       |     548     |        0        |      0      |
# |         FIRDA AYU AMALIA         |                 Akuntansi (S1)                |       201       |     450     |        0        |      0      |
# |             SUDIRAN              |         Pendidikan Bahasa Inggris (S2)        |       201       |     536     |        0        |      0      |
# |          DEWI NURJANNAH          |                 Manajemen (S1)                |       201       |     245     |        0        |      0      |
# |          ATIKA YULIANTI          |                Fisioterapi (S1)               |       199       |     357     |        0        |      0      |
# +----------------------------------+-----------------------------------------------+-----------------+-------------+-----------------+-------------+
# Scraping selesai! Data disimpan di 'sinta_authors.csv'.
